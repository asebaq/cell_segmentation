# %% [markdown]
# # Download data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget http://data.celltrackingchallenge.net/training-datasets/Fluo-N3DH-SIM+.zip
# !wget http://data.celltrackingchallenge.net/test-datasets/Fluo-N3DH-SIM+.zip
# !unzip Fluo-N3DH-SIM+.zip
# !mv /content/Fluo-N3DH-SIM+ "/content/drive/MyDrive/Colab Notebooks/3D segmentation/Fluo-N3DH-SIM+"

# %% [markdown]
# # Download code

# %%
# !git clone https://github.com/asebaq/cell_segmentation.git
# Out:
# Cloning into 'cell_segmentation'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 152 (delta 50), reused 133 (delta 31), pack-reused 0
# Receiving objects: 100% (152/152), 10.91 MiB | 19.47 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# !pip install -r cell_segmentation/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 42.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.6/91.6 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 73.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 65.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 95.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 28.8 MB/s eta 0:00:00
# ...

# %%
# !python ./cell_segmentation/patchify_data.py

# %%
# !python ./cell_segmentation/collect_dataset.py

# %%
# !python ./cell_segmentation/data_stats.py

# %%
# !cp -rf "/content/drive/MyDrive/Colab Notebooks/3D segmentation/Fluo-N3DH-SIM+_splitted" "/content/drive/MyDrive/Colab Notebooks/3D segmentation/Fluo-N3DH-SIM+_splitted_filtered"

# %%
# !python ./cell_segmentation/filter_patches.py
# Out:
# 100% 3630/3630 [00:50<00:00, 71.88it/s]
# 100% 420/420 [00:02<00:00, 141.64it/s]
# 100% 450/450 [00:03<00:00, 148.76it/s]

# %%
# !python ./cell_segmentation/collect_dataset.py
# Out:
#                                                 path  split
# 0  /content/drive/MyDrive/Colab Notebooks/3D segm...  train
# 1  /content/drive/MyDrive/Colab Notebooks/3D segm...  train
# 2  /content/drive/MyDrive/Colab Notebooks/3D segm...  train
# 3  /content/drive/MyDrive/Colab Notebooks/3D segm...  train
# 4  /content/drive/MyDrive/Colab Notebooks/3D segm...  train
# len(df) = 3243

# %%
#!python ./cell_segmentation/data_stats.py

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/3D segmentation/Fluo-N3DH-SIM+_splitted/data.csv" .
# !cp "/content/drive/MyDrive/Colab Notebooks/3D segmentation/Fluo-N3DH-SIM+_splitted_filtered/data.csv" .

# %%
# !python ./cell_segmentation/train.py
# Out:
# Train size: 2605
# Valid size: 286
# Test size: 352
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 346MB/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:478: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /content/lightning_logs
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:613: UserWarning: Checkpoint directory /content/drive/MyDrive/Colab Notebooks/3D segmentation/Fluo-N3DH-SIM+_splitted_filtered exists and is not empty.
# ...

# %%
# !cp -rf "/content/lightning_logs" "/content/drive/MyDrive/Colab Notebooks/3D segmentation/Fluo-N3DH-SIM+_splitted_filtered/lightning_logs_MA"

# %%
# !python ./cell_segmentation/inference.py
# Out:
# Traceback (most recent call last):
#   File "/content/./cell_segmentation/inference.py", line 57, in <module>
#     main(model_name, model_encoder, model_path, img_path)
#   File "/content/./cell_segmentation/inference.py", line 17, in main
#     checkpoint = torch.load(model_path)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 998, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 445, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 426, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'lightning_logs/version_0/checkpoints/Unet-resnet18-epoch009-0.8143.ckpt'
